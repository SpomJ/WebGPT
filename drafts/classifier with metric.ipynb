# %%
import nltk
nltk.download('punkt')
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Загрузка данных
data = pd.read_csv('train.csv')
train_data = data[:5000]
# Предварительная обработка текста
nltk.download('stopwords')
nltk.download('wordnet')
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    words = nltk.word_tokenize(text.lower())
    filtered_words = [word for word in words if word.isalnum() and word not in stop_words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
    return ' '.join(lemmatized_words)

train_data['processed_text'] = train_data['text'].apply(preprocess_text)

# Создание TF-IDF модели
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(train_data['processed_text'])
y = train_data['y']

# Обучение классификатора
classifier = make_pipeline(StandardScaler(with_mean=False), SVC())
classifier.fit(X, y)

# Функция для предсказания необходимости выхода в интернет для нового вопроса
def predict_internet_access(question):
    processed_question = preprocess_text(question)
    X_new = vectorizer.transform([processed_question])
    prediction = classifier.predict(X_new)
    if prediction[0] == 1:
        return 1, "Для ответа на этот вопрос требуется выход в интернет."
    else:
        return 0, "Для ответа на этот вопрос выход в интернет не требуется."

# Ввод нового вопроса с клавиатуры
new_question = input("Введите ваш вопрос: ")
print(predict_internet_access(new_question))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <ipython-input-34-77b8ff4d508d>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['processed_text'] = train_data['text'].apply(preprocess_text)
# Введите ваш вопрос: how many fingers does a person have on one hand?
# (0, 'Для ответа на этот вопрос выход в интернет не требуется.')

# %%
data = pd.read_csv('train.csv')

train_data = data[:5000]
test_data = data[5000:]

# %%
test_data
# Out:
#                                                    text  y
# 5000                            Who discovered tetanus?  0
# 5001             Who is the father of modern chemistry?  0
# 5002     What is the current status of MEA Flight ME 6?  1
# 5003                  What is Linus Pauling famous for?  0
# 5004  Who was the Roman Emperor during the peak of t...  0
# ...                                                 ... ..
# 5596             What are the places to visit in Spain?  1
# 5597       How do you avoid pickpockets when traveling?  0
# 5598   Who voiced Basil in 'The Great Mouse Detective'?  0
# 5599                     What is the axis of the Earth?  0
# 5600  What are the local coordinates for the Plitvic...  1
#
# [601 rows x 2 columns]

# %%
true_counter = 0

for t in test_data.itertuples():
    result, text = predict_internet_access(t.text)

    print(f'Question: {t.text}\nResult: {result}\n----------------\n')

    if result == t.y:
      true_counter += 1

true_counter / len(test_data)
# Out:
# Question: Who discovered tetanus?
# Result: 0
# ----------------
#
# Question: Who is the father of modern chemistry?
# Result: 0
# ----------------
#
# Question: What is the current status of MEA Flight ME 6?
# Result: 1
# ----------------
#
# Question: What is Linus Pauling famous for?
# Result: 0
# ----------------
#
# Question: Who was the Roman Emperor during the peak of the Roman Empire?
# Result: 1
# ----------------
#
# Question: What is an example of a commodity?
# Result: 0
# ----------------
#
# Question: What's the best walking route from Akihabara Station to the Ueno Zoo in Tokyo?
# Result: 1
# ----------------
#
# Question: What are the typical foods in Chile?
# Result: 1
# ----------------
#
# Question: Who are the most known Baroque painters?
# Result: 0
# ----------------
#
# Question: Which actor played 'Terminator' in the series?
# Result: 0
# ----------------
#
# Question: What is the Kuiper belt?
# Result: 0
# ----------------
#
# Question: What is the latest research on cancer therapy?
# Result: 1
# ----------------
#
# Question: Who discovered transistor?
# Result: 0
# ----------------
#
# Question: What is the meaning of 'romanticism' in art?
# Result: 0
# ----------------
#
# Question: How does iconography work in art?
# Result: 0
# ----------------
#
# Question: Describe the events leading up to the fall of the Aztec Empire.
# Result: 1
# ----------------
#
# Question: What are the recent technological advancements in electric cars?
# Result: 1
# ----------------
#
# Question: When does Cebu Pacific Flight 5J 18 land at HKG?
# Result: 1
# ----------------
#
# Question: What is ecotourism?
# Result: 0
# ----------------
#
# Question: Who is the main antagonist in 'Cinderella'?
# Result: 0
# ----------------
#
# Question: Who played 'Superman' in the 2013 movie 'Man of Steel'?
# Result: 0
# ----------------
#
# Question: What are the places to visit in Switzerland?
# Result: 1
# ----------------
#
# Question: What was the price of a pound of cheese in 2006?
# Result: 1
# ----------------
#
# Question: What are the recent advancements in the satellite launch by ISRO?
# Result: 0
# ----------------
#
# Question: What is a varsity jacket?
# Result: 0
# ----------------
#
# Question: What were the causes and consequences of the English Reformation?
# Result: 1
# ----------------
#
# Question: What led to the Cuban Missile Crisis during the Cold War?
# Result: 1
# ----------------
#
# Question: What was the price of a barrel of oil in 2002?
# Result: 1
# ----------------
#
# Question: Who is the main antagonist in the 'Harry Potter' series?
# Result: 0
# ----------------
#
# Question: What is a tectonic plate?
# Result: 0
# ----------------
#
# Question: What was the Edict of Nantes?
# Result: 0
# ----------------
#
# Question: Who was the first Prime Minister of Israel?
# Result: 1
# ----------------
#
# Question: What is liquidity?
# Result: 0
# ----------------
#
# Question: Who was the first President of the United States?
# Result: 0
# ----------------
#
# Question: What were the causes of the American Revolutionary War?
# Result: 1
# ----------------
#
# Question: What is the best beach in Spain?
# Result: 1
# ----------------
#
# Question: What is the purpose of art criticism?
# Result: 0
# ----------------
#
# Question: What city is known as 'The City of Lights'?
# Result: 0
# ----------------
#
# Question: What is a trapeze dress?
# Result: 0
# ----------------
#
# Question: What type of painting is 'The Scream' by Edvard Munch?
# Result: 0
# ----------------
#
# Question: What's the weather going to be like in New York tomorrow afternoon?
# Result: 1
# ----------------
#
# Question: Who invented the Electromagnetic telegraph?
# Result: 0
# ----------------
#
# Question: Who invented the Microwave oven?
# Result: 0
# ----------------
#
# Question: What did Wilhelm Conrad Roentgen contribute to physics?
# Result: 0
# ----------------
#
# Question: What is investing?
# Result: 0
# ----------------
#
# Question: What is CNN's customer service number in the UK?
# Result: 1
# ----------------
#
# Question: What's the navigational information from Seoul's Incheon Airport to the Gyeongbokgung Palace?
# Result: 1
# ----------------
#
# Question: What is the live status of Flight QZ123?
# Result: 1
# ----------------
#
# Question: What are must-visits in Cuba?
# Result: 0
# ----------------
#
# Question: What will be the evening temperature in Madrid next Monday?
# Result: 1
# ----------------
#
# Question: What is the current death toll in the Yemen civil war?
# Result: 1
# ----------------
#
# Question: What was the Weimar Republic?
# Result: 0
# ----------------
#
# Question: How are black holes formed?
# Result: 0
# ----------------
#
# Question: What were the causes and results of the Spanish Civil War?
# Result: 1
# ----------------
#
# Question: What is a traditional IRA?
# Result: 0
# ----------------
#
# Question: What is a choker necklace?
# Result: 0
# ----------------
#
# Question: What is a deed?
# Result: 0
# ----------------
#
# Question: What's the current traffic situation near the Brooklyn Bridge in New York?
# Result: 1
# ----------------
#
# Question: What are the places to visit in Frankfurt?
# Result: 1
# ----------------
#
# Question: What is a satellite?
# Result: 0
# ----------------
#
# Question: What was the cost of a barrel of oil in 2008?
# Result: 1
# ----------------
#
# Question: What was the price of soybeans in July 2007?
# Result: 1
# ----------------
#
# Question: Who discovered the law of conservation of energy?
# Result: 0
# ----------------
#
# Question: Who discovered insulin?
# Result: 0
# ----------------
#
# Question: How's the weather in Amsterdam right now?
# Result: 1
# ----------------
#
# Question: What is deportation?
# Result: 0
# ----------------
#
# Question: What is an ulster coat?
# Result: 0
# ----------------
#
# Question: What are rights of the accused?
# Result: 0
# ----------------
#
# Question: Who invented the Microprocessor?
# Result: 0
# ----------------
#
# Question: What was the price of a pound of nickel in 2005?
# Result: 1
# ----------------
#
# Question: What did Paul Samuelson contribute to economics?
# Result: 0
# ----------------
#
# Question: What is an electron?
# Result: 0
# ----------------
#
# Question: What is a visit to an art gallery?
# Result: 0
# ----------------
#
# Question: What is a sheath dress?
# Result: 0
# ----------------
#
# Question: What is the Twitter support email in the USA?
# Result: 1
# ----------------
#
# Question: When was the end of the Cold War?
# Result: 0
# ----------------
#
# Question: Who directed 'The Emperor's New Groove'?
# Result: 0
# ----------------
#
# Question: What is the best time to visit New Zealand?
# Result: 1
# ----------------
#
# Question: Who came up with the concept of evolution?
# Result: 1
# ----------------
#
# Question: Who discovered the structure of DNA?
# Result: 0
# ----------------
#
# Question: Who discovered the String theory?
# Result: 0
# ----------------
#
# Question: Who discovered oxygen?
# Result: 0
# ----------------
#
# Question: What is the onboard service for Turkish Airlines Flight TK 8?
# Result: 1
# ----------------
#
# Question: What is the address of the World Bank in Washington?
# Result: 0
# ----------------
#
# Question: What is a waistcoat?
# Result: 0
# ----------------
#
# Question: Who directed 'The Black Cauldron'?
# Result: 0
# ----------------
#
# Question: Who proposed the germ theory of disease?
# Result: 0
# ----------------
#
# Question: What is a gravitational wave?
# Result: 0
# ----------------
#
# Question: How did the Battle of Hastings change England?
# Result: 0
# ----------------
#
# Question: Who voiced Sulley in 'Monsters, Inc.'?
# Result: 0
# ----------------
#
# Question: What was the Hartford Convention?
# Result: 0
# ----------------
#
# Question: What was the price of a kilogram of yerba mate in 2003?
# Result: 1
# ----------------
#
# Question: What are jellies shoes?
# Result: 0
# ----------------
#
# Question: What were the causes and outcomes of the Paraguayan War?
# Result: 1
# ----------------
#
# Question: What's the fastest route to navigate from Charles de Gaulle Airport to the Palace of Versailles?
# Result: 1
# ----------------
#
# Question: Does Emirates Flight EK 202 provide amenities like blankets and pillows?
# Result: 1
# ----------------
#
# Question: Who is the current richest person in the world?
# Result: 1
# ----------------
#
# Question: Who is Ivan Pavlov?
# Result: 0
# ----------------
#
# Question: What is the role of women in Art - both as its creator and subjects?
# Result: 0
# ----------------
#
# Question: Who discovered radium?
# Result: 0
# ----------------
#
# Question: Who directed 'Snow White and the Seven Dwarfs'?
# Result: 0
# ----------------
#
# Question: What was the cost of a pound of cocoa beans in 2015?
# Result: 1
# ----------------
#
# Question: What is a landscape in art?
# Result: 0
# ----------------
#
# Question: What's the approximate driving time from JFK Airport to The Museum of Modern Art in New York?
# Result: 1
# ----------------
#
# Question: Who discovered the Dual nature of light?
# Result: 0
# ----------------
#
# Question: What is insider trading?
# Result: 0
# ----------------
#
# Question: What museums are must-visits in Washington D.C.?
# Result: 0
# ----------------
#
# Question: What is the current wind gust speed in Wellington?
# Result: 0
# ----------------
#
# Question: Who discovered the hydrogen atom?
# Result: 0
# ----------------
#
# Question: What are the recent advancements in quantum computing?
# Result: 1
# ----------------
#
# Question: What is the latest news about the measles outbreak worldwide?
# Result: 1
# ----------------
#
# Question: What is aerospace engineering?
# Result: 0
# ----------------
#
# Question: Has Hawaiian Airlines Flight HA 51 been delayed?
# Result: 1
# ----------------
#
# Question: What is a bed and breakfast?
# Result: 0
# ----------------
#
# Question: What is the contact number for the University of Northern British Columbia?
# Result: 1
# ----------------
#
# Question: What was the price of palladium in July 1999?
# Result: 1
# ----------------
#
# Question: What are the main things to do in Canada?
# Result: 1
# ----------------
#
# Question: What's the preferred navigation route from Vienna International Airport to the Schonbrunn Palace?
# Result: 1
# ----------------
#
# Question: What were the key events during the Battle of Stalingrad?
# Result: 0
# ----------------
#
# Question: Where did scientist Nikola Tesla conduct his most recent scientific experiment?
# Result: 1
# ----------------
#
# Question: What was the price of a kilogram of sunflower seed in 2003?
# Result: 1
# ----------------
#
# Question: What are the inventors of the telescope?
# Result: 0
# ----------------
#
# Question: What was China's political environment like during the Cultural Revolution?
# Result: 1
# ----------------
#
# Question: Who discovered the principles of how we see color?
# Result: 0
# ----------------
#
# Question: What is the Van Allen belt?
# Result: 0
# ----------------
#
# Question: What is earnest money?
# Result: 0
# ----------------
#
# Question: How did Isaac Newton change our understanding of the universe?
# Result: 0
# ----------------
#
# Question: How important are Art and Music in our culture?
# Result: 0
# ----------------
#
# Question: What's the traffic status near Marina Bay Sands in Singapore right now?
# Result: 1
# ----------------
#
# Question: What is the University of New Brunswick's telephone number?
# Result: 1
# ----------------
#
# Question: Has Air Algerie Flight AH 1004 changed its gate?
# Result: 1
# ----------------
#
# Question: What was the cost of a ton of zinc in 2004?
# Result: 1
# ----------------
#
# Question: Does British Airways Flight BA 112 have power outlets at the seats?
# Result: 1
# ----------------
#
# Question: What were the causes and outcomes of the Boxer Rebellion?
# Result: 1
# ----------------
#
# Question: Who directed 'The Princess and the Frog'?
# Result: 0
# ----------------
#
# Question: What is the traditional dish of Luxembourg?
# Result: 1
# ----------------
#
# Question: What was the cost of a kilogram of chamomile in 2008?
# Result: 1
# ----------------
#
# Question: How can I contact the University of Hong Kong?
# Result: 1
# ----------------
#
# Question: What is interrogation?
# Result: 0
# ----------------
#
# Question: What's the current air pressure in Paris?
# Result: 1
# ----------------
#
# Question: What is a supernova?
# Result: 0
# ----------------
#
# Question: What did Robert Hooke discover in Microscopy?
# Result: 0
# ----------------
#
# Question: What is a balance of trade?
# Result: 0
# ----------------
#
# Question: What is a skills assessment?
# Result: 0
# ----------------
#
# Question: Who discovered the laws of heredity?
# Result: 0
# ----------------
#
# Question: What is the current temperature in New York City?
# Result: 1
# ----------------
#
# Question: How were the ancient Greek city-states established?
# Result: 0
# ----------------
#
# Question: What is a cap sleeve?
# Result: 0
# ----------------
#
# Question: What flights are delayed at Los Angeles International Airport today?
# Result: 1
# ----------------
#
# Question: Who is the main antagonist in 'Fantasia'?
# Result: 0
# ----------------
#
# Question: What is the distance from Madrid airport to the city center?
# Result: 1
# ----------------
#
# Question: What is the local area name for the region surrounding the Great Wall of China?
# Result: 1
# ----------------
#
# Question: Has Air China Flight CA 981 changed its departure time?
# Result: 1
# ----------------
#
# Question: How do tariffs impact the economy?
# Result: 0
# ----------------
#
# Question: What is a planet?
# Result: 0
# ----------------
#
# Question: What was the price of barley in October 2011?
# Result: 1
# ----------------
#
# Question: What were the causes and impacts of the Sino-Japanese Wars?
# Result: 1
# ----------------
#
# Question: What is the best time to visit Florence?
# Result: 1
# ----------------
#
# Question: What is a trumpet skirt?
# Result: 0
# ----------------
#
# Question: What is worn under a kimono?
# Result: 0
# ----------------
#
# Question: What is a mandala in art?
# Result: 0
# ----------------
#
# Question: Who is the main antagonist in 'The Little Mermaid'?
# Result: 0
# ----------------
#
# Question: What is a scoop neck?
# Result: 0
# ----------------
#
# Question: What is the current status of British Airways flight BA2022?
# Result: 1
# ----------------
#
# Question: How can I get in touch with Reddit's customer service?
# Result: 1
# ----------------
#
# Question: What is the latest on Russia's invasion of Ukraine?
# Result: 1
# ----------------
#
# Question: Did Air Canada Flight AC 849 depart on time from London Heathrow?
# Result: 1
# ----------------
#
# Question: What is a dictator?
# Result: 0
# ----------------
#
# Question: What is collective bargaining?
# Result: 0
# ----------------
#
# Question: Why is Jane Goodall famous?
# Result: 0
# ----------------
#
# Question: What is a sculpture made of?
# Result: 0
# ----------------
#
# Question: What is gravity?
# Result: 0
# ----------------
#
# Question: What is the gate number for Air Greenland Flight GL 782?
# Result: 1
# ----------------
#
# Question: What's the recipe for a 'Death by Chocolate' cake as per Nigella Lawson's cookbook?
# Result: 1
# ----------------
#
# Question: What is the latest on the restoration of any ancient monument in any country?
# Result: 1
# ----------------
#
# Question: What's the parking area close to Château d'If in Marseille according to the local map?
# Result: 1
# ----------------
#
# Question: What are the best local cafes to visit in Barcelona based on recent review?
# Result: 1
# ----------------
#
# Question: What ancient sites can be found in Jordan?
# Result: 1
# ----------------
#
# Question: What were the key events leading up to the Haitian Revolution?
# Result: 1
# ----------------
#
# Question: Who invented the Quantum computing?
# Result: 1
# ----------------
#
# Question: What are the things to do in Miami?
# Result: 1
# ----------------
#
# Question: Who were the Pharaohs of Egypt?
# Result: 1
# ----------------
#
# Question: What is a cable knit?
# Result: 0
# ----------------
#
# Question: What is a tunic?
# Result: 0
# ----------------
#
# Question: Has Philippine Airlines Flight PR 102 taken off yet?
# Result: 1
# ----------------
#
# Question: What is the visibility condition in Lisbon?
# Result: 1
# ----------------
#
# Question: What is Marie Sklodowska Curie known for?
# Result: 0
# ----------------
#
# Question: What is the National University of Singapore's support phone number?
# Result: 1
# ----------------
#
# Question: Who invented the Personal Computer?
# Result: 0
# ----------------
#
# Question: What do plants exhale?
# Result: 0
# ----------------
#
# Question: Who played 'Spiderman' in the 2019 movie 'Spiderman: Far From Home'?
# Result: 0
# ----------------
#
# Question: What is a flatform?
# Result: 0
# ----------------
#
# Question: What is the email address for the University of Windsor?
# Result: 1
# ----------------
#
# Question: What did Ada Lovelace contribute to computing?
# Result: 0
# ----------------
#
# Question: What is a poet sleeve?
# Result: 0
# ----------------
#
# Question: Who invented the printing press?
# Result: 0
# ----------------
#
# Question: What is the latest significant advancement in the study of dark matter?
# Result: 0
# ----------------
#
# Question: What is the Facebook help center's contact information?
# Result: 1
# ----------------
#
# Question: What will be the nighttime temperature in Berlin next Tuesday?
# Result: 1
# ----------------
#
# Question: What is the Dyson sphere?
# Result: 0
# ----------------
#
# Question: What was the average price of pork in 2016?
# Result: 1
# ----------------
#
# Question: What are the top attractions in Manhattan?
# Result: 1
# ----------------
#
# Question: What's the current temperature in Ibiza?
# Result: 1
# ----------------
#
# Question: What is the best route to travel from Edinburgh Airport to the Royal Mile?
# Result: 1
# ----------------
#
# Question: What is the meaning of a red rose in art?
# Result: 0
# ----------------
#
# Question: What's the sunrise and sunset time in Paris tomorrow?
# Result: 1
# ----------------
#
# Question: What festivals are celebrated in Brazil?
# Result: 1
# ----------------
#
# Question: Who discovered principles of classical conditioning?
# Result: 0
# ----------------
#
# Question: What was the cost of pork bellies per pound in 2000?
# Result: 1
# ----------------
#
# Question: What was the highest price of platinum in the past five years?
# Result: 1
# ----------------
#
# Question: What did Ludwig Boltzmann contribute to statistical mechanics?
# Result: 0
# ----------------
#
# Question: What's the fastest route from Logan International Airport to Fenway Park in Boston?
# Result: 1
# ----------------
#
# Question: What's the sunrise and sunset time in New York tomorrow?
# Result: 1
# ----------------
#
# Question: Who is the main antagonist in 'Chicken Little'?
# Result: 0
# ----------------
#
# Question: What were the causes of World War I?
# Result: 1
# ----------------
#
# Question: What is a treaty?
# Result: 0
# ----------------
#
# Question: What is a meditation retreat?
# Result: 0
# ----------------
#
# Question: What elements did Marie and Pierre Curie isolate?
# Result: 0
# ----------------
#
# Question: What is sustainable development?
# Result: 1
# ----------------
#
# Question: What was the average price of lumber in May 2011?
# Result: 1
# ----------------
#
# Question: Where was the first World's Fair held?
# Result: 0
# ----------------
#
# Question: What is the current temperature in Moscow?
# Result: 1
# ----------------
#
# Question: What is the latest news on any school shooting incident?
# Result: 1
# ----------------
#
# Question: What are the local coordinates for Historic Centre of Prague in the Czech Republic?
# Result: 1
# ----------------
#
# Question: Who invented the first practical automobile?
# Result: 0
# ----------------
#
# Question: What is the importance of researching local customs before traveling?
# Result: 0
# ----------------
#
# Question: Are there any flight cancellations at JFK airport today?
# Result: 1
# ----------------
#
# Question: What's the local traffic condition around Namdaemun Gate in Seoul right now?
# Result: 1
# ----------------
#
# Question: Who discovered antimatter?
# Result: 0
# ----------------
#
# Question: What is the Chandrasekhar limit?
# Result: 1
# ----------------
#
# Question: What is friction?
# Result: 0
# ----------------
#
# Question: How much is the humidity level in Mumbai currently?
# Result: 1
# ----------------
#
# Question: Who voiced Flynn Rider in 'Tangled'?
# Result: 0
# ----------------
#
# Question: What is a lobbyist?
# Result: 0
# ----------------
#
# Question: What is freelancing?
# Result: 0
# ----------------
#
# Question: What are the recent developments in the overall Dam condition in China?
# Result: 1
# ----------------
#
# Question: Who was in power in Britain during the signing of the Treaty of Versailles in 1919?
# Result: 0
# ----------------
#
# Question: Who is the main antagonist in 'Ratatouille'?
# Result: 0
# ----------------
#
# Question: What is cosmic censorship?
# Result: 0
# ----------------
#
# Question: Who invented the Flying shuttle?
# Result: 0
# ----------------
#
# Question: What are the recent developments in inter-Korean relations?
# Result: 1
# ----------------
#
# Question: Where is the University College Dublin's office?
# Result: 1
# ----------------
#
# Question: What will be the afternoon temperature in Paris next Monday?
# Result: 1
# ----------------
#
# Question: Who invented gunpowder?
# Result: 0
# ----------------
#
# Question: What is the Golden Age of Dutch art?
# Result: 0
# ----------------
#
# Question: What is the most expensive painting ever sold?
# Result: 1
# ----------------
#
# Question: What is a capital account?
# Result: 0
# ----------------
#
# Question: Who directed 'Coco'?
# Result: 0
# ----------------
#
# Question: What was the cost of a kilogram of adzuki beans in 2008?
# Result: 1
# ----------------
#
# Question: What is the dew point in Rome currently?
# Result: 1
# ----------------
#
# Question: Who discovered infrared radiation?
# Result: 0
# ----------------
#
# Question: What was the price of chicken in June 2014?
# Result: 1
# ----------------
#
# Question: What is symbiosis?
# Result: 0
# ----------------
#
# Question: What are recent developments in the privacy policy of any tech giant?
# Result: 0
# ----------------
#
# Question: What was the price of wheat in US dollars per bushel in May 2004?
# Result: 1
# ----------------
#
# Question: Who voiced Carl in 'Up'?
# Result: 0
# ----------------
#
# Question: What did Svante Arrhenius propose in his ionic theory?
# Result: 0
# ----------------
#
# Question: What is cost-push inflation?
# Result: 0
# ----------------
#
# Question: What are the recent developments in the protection of the Arctic region?
# Result: 1
# ----------------
#
# Question: Who voiced Sally in 'The Nightmare Before Christmas'?
# Result: 0
# ----------------
#
# Question: What is the democracy index?
# Result: 0
# ----------------
#
# Question: Who proposed the heliocentric model?
# Result: 0
# ----------------
#
# Question: What is the helpline for the Khan Academy?
# Result: 1
# ----------------
#
# Question: What is foreign policy?
# Result: 0
# ----------------
#
# Question: What were the key events and outcomes of the Japanese invasion of Manchuria?
# Result: 1
# ----------------
#
# Question: What are the must-visit places in Montenegro?
# Result: 1
# ----------------
#
# Question: Are there any extreme weather alerts for Seattle today?
# Result: 1
# ----------------
#
# Question: What is a comet?
# Result: 0
# ----------------
#
# Question: What were the causes and impacts of the French and Indian War?
# Result: 1
# ----------------
#
# Question: What was the purpose of the Apollo missions?
# Result: 0
# ----------------
#
# Question: Who were the Allied Powers in World War II?
# Result: 0
# ----------------
#
# Question: What's the best walking route from BTS Siam Station to the Art in Paradise Bangkok Museum?
# Result: 1
# ----------------
#
# Question: What's the walking distance from the Parthenon to Syntagma Square in Athens?
# Result: 1
# ----------------
#
# Question: How is expressionism different from impressionism?
# Result: 0
# ----------------
#
# Question: What is a travel itinerary?
# Result: 1
# ----------------
#
# Question: Who directed 'WALL-E'?
# Result: 0
# ----------------
#
# Question: What is sovereignty?
# Result: 0
# ----------------
#
# Question: Who is the current World Chess Champion?
# Result: 1
# ----------------
#
# Question: What is linen?
# Result: 0
# ----------------
#
# Question: What was the cost of a kilogram of wool in 2008?
# Result: 1
# ----------------
#
# Question: How often are Lufthansa Flight LH 400 delayed?
# Result: 1
# ----------------
#
# Question: What was the cost of a pound of coffee in 2006?
# Result: 1
# ----------------
#
# Question: What is a landlord?
# Result: 0
# ----------------
#
# Question: What is tax evasion?
# Result: 0
# ----------------
#
# Question: What is private equity?
# Result: 0
# ----------------
#
# Question: What is a space law?
# Result: 0
# ----------------
#
# Question: What was the cost of a kilogram of olive oil in 2008?
# Result: 1
# ----------------
#
# Question: Who is famous for his uncertainty principle?
# Result: 0
# ----------------
#
# Question: What language is primarily spoken in Spain?
# Result: 0
# ----------------
#
# Question: What is the meaning of 'kitsch' in art?
# Result: 0
# ----------------
#
# Question: Does Air India Flight AI 102 offer inflight Wi-Fi?
# Result: 1
# ----------------
#
# Question: What's the exact location of Zion National Park Utah according to a local Utah map?
# Result: 1
# ----------------
#
# Question: What was the price of a barrel of oil in 2005?
# Result: 1
# ----------------
#
# Question: What is the walking distance from Times Square to Central Park in New York?
# Result: 1
# ----------------
#
# Question: Where is the University of Delhi office?
# Result: 1
# ----------------
#
# Question: Which universities did Marie Curie attend at her doctorate level?
# Result: 0
# ----------------
#
# Question: What was the Iran-Contra affair?
# Result: 0
# ----------------
#
# Question: What is a title search?
# Result: 0
# ----------------
#
# Question: When did the Vietnam War end?
# Result: 0
# ----------------
#
# Question: Who was the Spanish king during the Spanish Armada?
# Result: 0
# ----------------
#
# Question: What's the weather forecast for next Wednesday in Paris?
# Result: 1
# ----------------
#
# Question: What is herringbone?
# Result: 0
# ----------------
#
# Question: What was the closing price of the S&P 500 yesterday?
# Result: 1
# ----------------
#
# Question: Does Lufthansa Flight LH 400 have Wi-Fi?
# Result: 1
# ----------------
#
# Question: What is the Langara College's telephone number?
# Result: 1
# ----------------
#
# Question: What element has the symbol K?
# Result: 0
# ----------------
#
# Question: What was the cost of a ton of aluminum in 2020?
# Result: 1
# ----------------
#
# Question: What is the Tolman-Oppenheimer-Volkoff limit?
# Result: 1
# ----------------
#
# Question: What were the main events during the Persian Gulf War?
# Result: 1
# ----------------
#
# Question: Why is Cubism called Cubism?
# Result: 0
# ----------------
#
# Question: What were the key events and outcomes of the Hundred Years' War with England?
# Result: 1
# ----------------
#
# Question: What is the temperature in New York right now?
# Result: 1
# ----------------
#
# Question: What is a sabbatical?
# Result: 0
# ----------------
#
# Question: What's the exact local map location for Petra in Jordan?
# Result: 1
# ----------------
#
# Question: What is the main function of the judicial branch?
# Result: 0
# ----------------
#
# Question: How did the Punic Wars impact Rome's expansion?
# Result: 1
# ----------------
#
# Question: What is monetary policy?
# Result: 0
# ----------------
#
# Question: What are stilettos?
# Result: 0
# ----------------
#
# Question: What happened during the Napoleonic Wars?
# Result: 1
# ----------------
#
# Question: How's the weather in Hawaii today?
# Result: 1
# ----------------
#
# Question: What is the farthest planet from the sun?
# Result: 0
# ----------------
#
# Question: What was the price of a pound of silver in 2006?
# Result: 1
# ----------------
#
# Question: Who is the director of the 'Lord of the Rings' series?
# Result: 0
# ----------------
#
# Question: What is forensic science?
# Result: 0
# ----------------
#
# Question: What is the Eurozone?
# Result: 0
# ----------------
#
# Question: What is propaganda?
# Result: 0
# ----------------
#
# Question: Why did Germany and Soviet Union attack Poland in World War II?
# Result: 1
# ----------------
#
# Question: Who directed 'Sleeping Beauty'?
# Result: 0
# ----------------
#
# Question: What were the causes and outcomes of the Sepoy Mutiny?
# Result: 1
# ----------------
#
# Question: When did the Civil War happen in the United States?
# Result: 0
# ----------------
#
# Question: Has Qantas Flight QF 12 started boarding?
# Result: 1
# ----------------
#
# Question: What is legal precedent?
# Result: 0
# ----------------
#
# Question: What is the current distance between the earth and the mars?
# Result: 1
# ----------------
#
# Question: What were the causes of the French Revolution?
# Result: 1
# ----------------
#
# Question: What was the price of a bushel of soybeans in September 2010?
# Result: 1
# ----------------
#
# Question: What were the causes and outcomes of the American Revolution?
# Result: 1
# ----------------
#
# Question: Who invented the ATM machine?
# Result: 0
# ----------------
#
# Question: What is an astronaut?
# Result: 0
# ----------------
#
# Question: What is the current location of the Hubble Space Telescope?
# Result: 0
# ----------------
#
# Question: What is the weather forecast for London tomorrow?
# Result: 1
# ----------------
#
# Question: What is the procedure for going through customs?
# Result: 0
# ----------------
#
# Question: What are the famous dishes in Andorra?
# Result: 1
# ----------------
#
# Question: What's the navigation information from Seoul's Incheon Airport to Bukchon Hanok Village?
# Result: 1
# ----------------
#
# Question: What is the address of the University of Morocco?
# Result: 1
# ----------------
#
# Question: What is the recent update on the situation of prisoners in North Korea?
# Result: 1
# ----------------
#
# Question: What is a vacation rental?
# Result: 0
# ----------------
#
# Question: Why is it important to follow local customs and regulations?
# Result: 1
# ----------------
#
# Question: What marked the end of the Cold War?
# Result: 0
# ----------------
#
# Question: What is the meaning of a white lily in art?
# Result: 0
# ----------------
#
# Question: What is the current unemployment rate in the U.S.?
# Result: 0
# ----------------
#
# Question: What is the latest update on Elon Musk's space missions?
# Result: 1
# ----------------
#
# Question: Who invented Botox?
# Result: 0
# ----------------
#
# Question: What is a seller's market?
# Result: 0
# ----------------
#
# Question: What's the recommended navigation route from the Gare du Nord to the Eiffel tower?
# Result: 1
# ----------------
#
# Question: Who is Galileo Galilei?
# Result: 0
# ----------------
#
# Question: What is the departure time for Lion Air Flight JT 1?
# Result: 1
# ----------------
#
# Question: Who proposed the Bohr atomic model?
# Result: 0
# ----------------
#
# Question: What was the price of a dozen eggs in 2010?
# Result: 1
# ----------------
#
# Question: What's the navigation information from Phoenix Sky Harbor Airport to Camelback Mountain?
# Result: 1
# ----------------
#
# Question: What's the walking distance from the Uffizi Gallery to the Florence Cathedral in Florence?
# Result: 1
# ----------------
#
# Question: What is the latest update on the COVID-19 pandemic?
# Result: 1
# ----------------
#
# Question: What's the exact local map location for the Golden Gate Bridge in San Francisco?
# Result: 1
# ----------------
#
# Question: What did Barbara McClintock discover?
# Result: 0
# ----------------
#
# Question: What is a henley shirt?
# Result: 0
# ----------------
#
# Question: What is a technology demonstration satellite?
# Result: 0
# ----------------
#
# Question: What's the approximate driving time from Los Angeles International Airport to the Hollywood Sign?
# Result: 1
# ----------------
#
# Question: What is a merger?
# Result: 0
# ----------------
#
# Question: How much did a pound of cotton cost in 2010?
# Result: 1
# ----------------
#
# Question: What was the price of a barrel of Brent Crude Oil in 2004?
# Result: 1
# ----------------
#
# Question: What are the latest research findings in dark matter?
# Result: 1
# ----------------
#
# Question: What was the highest recorded price of soybeans in 2012?
# Result: 1
# ----------------
#
# Question: Who are the Supreme Court Justices?
# Result: 0
# ----------------
#
# Question: What is the significance of V-J Day?
# Result: 0
# ----------------
#
# Question: What and when was the Teapot Dome Scandal?
# Result: 0
# ----------------
#
# Question: What is the latest news on Boris Johnson's leadership?
# Result: 1
# ----------------
#
# Question: What are the consequences of the American Civil War?
# Result: 1
# ----------------
#
# Question: Who is the main antagonist in 'Treasure Planet'?
# Result: 0
# ----------------
#
# Question: What's the approximate driving time from Hangzhou Xiaoshan International Airport to the West Lake?
# Result: 1
# ----------------
#
# Question: What is arms race?
# Result: 0
# ----------------
#
# Question: Name a country in Africa?
# Result: 0
# ----------------
#
# Question: What were the causes and consequences of the Russo-Turkish War?
# Result: 1
# ----------------
#
# Question: What is autocracy?
# Result: 0
# ----------------
#
# Question: What is a sublease?
# Result: 0
# ----------------
#
# Question: Where is the Vancouver Community College located?
# Result: 0
# ----------------
#
# Question: What was the cost of a kilogram of cottonseed oil in 2008?
# Result: 1
# ----------------
#
# Question: What is a city trip?
# Result: 0
# ----------------
#
# Question: What is constitutional monarchy?
# Result: 0
# ----------------
#
# Question: What was the aftermath of the Vietnam War for the United States?
# Result: 1
# ----------------
#
# Question: Who directed the 'Terminator' series?
# Result: 0
# ----------------
#
# Question: What did Enrico Fermi accomplish in nuclear physics?
# Result: 0
# ----------------
#
# Question: What is an economic depression?
# Result: 0
# ----------------
#
# Question: What is the local map grid reference for the Acropolis of Athens?
# Result: 1
# ----------------
#
# Question: What's the weather forecast for next Friday in Berlin?
# Result: 1
# ----------------
#
# Question: What is a chromosome?
# Result: 0
# ----------------
#
# Question: Where are the subway stations in Manhattan?
# Result: 0
# ----------------
#
# Question: What is the Herschel Space Observatory?
# Result: 0
# ----------------
#
# Question: What was the Manhattan Project?
# Result: 0
# ----------------
#
# Question: What was the score of the 2022 Super Bowl?
# Result: 0
# ----------------
#
# Question: Who voiced EVE in 'WALL-E'?
# Result: 0
# ----------------
#
# Question: What does a prism do to light?
# Result: 0
# ----------------
#
# Question: What is a career assessment?
# Result: 0
# ----------------
#
# Question: What is the meaning of the term 'memento mori' in art?
# Result: 0
# ----------------
#
# Question: How much did a tonne of lead cost in 2003?
# Result: 1
# ----------------
#
# Question: What did Niels Bohr contribute to quantum physics?
# Result: 0
# ----------------
#
# Question: How is Art Deco characterized?
# Result: 0
# ----------------
#
# Question: Who directed 'Tinker Bell'?
# Result: 0
# ----------------
#
# Question: Who voiced Piglet in 'The Many Adventures of Winnie the Pooh'?
# Result: 0
# ----------------
#
# Question: What language is primarily spoken in Russia?
# Result: 0
# ----------------
#
# Question: What is a flat rate?
# Result: 0
# ----------------
#
# Question: What is the current employment rate in Canada?
# Result: 1
# ----------------
#
# Question: What was the cost of Rough Rice per pound in 2012?
# Result: 1
# ----------------
#
# Question: What was the copper price in December 1996?
# Result: 1
# ----------------
#
# Question: How has digital technology influenced contemporary art?
# Result: 0
# ----------------
#
# Question: What are amino acids?
# Result: 0
# ----------------
#
# Question: What is doodling?
# Result: 0
# ----------------
#
# Question: What were the main events during the Japanese invasion of Nanking?
# Result: 0
# ----------------
#
# Question: What is a tornado?
# Result: 0
# ----------------
#
# Question: What is antibiotic resistance?
# Result: 0
# ----------------
#
# Question: What is a geocentric model of the universe?
# Result: 0
# ----------------
#
# Question: What will the weather be like in Mumbai next Sunday?
# Result: 1
# ----------------
#
# Question: What was the cost of a kilogram of tangerines in 2008?
# Result: 1
# ----------------
#
# Question: Who invented the cotton gin?
# Result: 0
# ----------------
#
# Question: What's the local traffic condition around the Chain Bridge in Budapest right now?
# Result: 1
# ----------------
#
# Question: What are the main attractions in Peru?
# Result: 1
# ----------------
#
# Question: What city is known as 'The City of Angels'?
# Result: 1
# ----------------
#
# Question: What is the University of Prince Edward Island's customer service hotline?
# Result: 1
# ----------------
#
# Question: What is a man-made wonder?
# Result: 0
# ----------------
#
# Question: What did Johannes Kepler discover?
# Result: 0
# ----------------
#
# Question: What is a keyhole neckline?
# Result: 0
# ----------------
#
# Question: What is a money order?
# Result: 0
# ----------------
#
# Question: What is the recent development in any high profile murder case?
# Result: 1
# ----------------
#
# Question: Has Iran Air Flight IR 800 been delayed?
# Result: 1
# ----------------
#
# Question: Who invented the radio?
# Result: 0
# ----------------
#
# Question: What is a current account?
# Result: 0
# ----------------
#
# Question: What is the cuisine of China?
# Result: 1
# ----------------
#
# Question: What is a stock option?
# Result: 0
# ----------------
#
# Question: What type of aircraft is used for Emirates Flight EK 1?
# Result: 1
# ----------------
#
# Question: Who voiced Duchess in 'The Aristocats'?
# Result: 0
# ----------------
#
# Question: What is an emergency fund?
# Result: 0
# ----------------
#
# Question: What is totalitarianism?
# Result: 0
# ----------------
#
# Question: What is an all-inclusive resort?
# Result: 1
# ----------------
#
# Question: What was the Tet Offensive?
# Result: 0
# ----------------
#
# Question: What is atom?
# Result: 0
# ----------------
#
# Question: What was the price of a kilogram of mustard in 2003?
# Result: 1
# ----------------
#
# Question: Who is the main antagonist in 'Brave'?
# Result: 0
# ----------------
#
# Question: What is the current exchange rate between the US dollar and the Euro?
# Result: 1
# ----------------
#
# Question: What is the recent status of any Royal Family?
# Result: 0
# ----------------
#
# Question: How do you find the best restaurants when traveling?
# Result: 0
# ----------------
#
# Question: What's the fastest route from Arrivals in Pearson Airport to the Toronto Zoo?
# Result: 1
# ----------------
#
# Question: Where is the Royal Holloway, University of London's office?
# Result: 1
# ----------------
#
# Question: What is dark matter?
# Result: 0
# ----------------
#
# Question: What traditional platforms are used for fishing in Polynesia?
# Result: 0
# ----------------
#
# Question: Who invented logarithms?
# Result: 0
# ----------------
#
# Question: What's the exact local map location for Machu Picchu in Peru?
# Result: 1
# ----------------
#
# Question: What is the Drake equation?
# Result: 0
# ----------------
#
# Question: Who played Frodo in 'The Lord of the Rings'?
# Result: 0
# ----------------
#
# Question: What is a grant?
# Result: 0
# ----------------
#
# Question: Who invented the internet?
# Result: 0
# ----------------
#
# Question: Do all the seats in United Airlines Flight UA 880 have power outlets?
# Result: 1
# ----------------
#
# Question: What was the price of a barrel of gasoline in 2007?
# Result: 1
# ----------------
#
# Question: What's the current weather condition in Miami?
# Result: 1
# ----------------
#
# Question: What is the departure terminal for Emirates Flight EK 202?
# Result: 1
# ----------------
#
# Question: What is the latest exhibition being held at the Louvre museum?
# Result: 1
# ----------------
#
# Question: What is a white dwarf?
# Result: 0
# ----------------
#
# Question: What are the top tourist attractions in Amsterdam?
# Result: 1
# ----------------
#
# Question: What type of seats are there on Emirates Flight EK 201?
# Result: 1
# ----------------
#
# Question: What is a two-party system?
# Result: 0
# ----------------
#
# Question: Who popularized the bob haircut?
# Result: 0
# ----------------
#
# Question: What is Laval University's telephone number?
# Result: 1
# ----------------
#
# Question: What is the expected high temperature in Sydney tomorrow?
# Result: 1
# ----------------
#
# Question: Who is Rosalind Franklin?
# Result: 0
# ----------------
#
# Question: What are the must see sites in Zurich?
# Result: 1
# ----------------
#
# Question: What's the best route from Copenhagen Airport to the Little Mermaid statue?
# Result: 1
# ----------------
#
# Question: What is identity theft?
# Result: 0
# ----------------
#
# Question: What were the significant events during the Hundred Years’ War?
# Result: 1
# ----------------
#
# Question: What is Nike's customer service number in Germany?
# Result: 1
# ----------------
#
# Question: Where is the nearest Starbucks to the Eiffel Tower in Paris?
# Result: 1
# ----------------
#
# Question: Why does the moon not have its own light?
# Result: 0
# ----------------
#
# Question: What were the causes and outcomes of the American Indian Wars?
# Result: 1
# ----------------
#
# Question: What was the price of a pound of coffee in 2005?
# Result: 1
# ----------------
#
# Question: What is the purpose of bug repellent for certain travel destinations?
# Result: 0
# ----------------
#
# Question: What's the quickest route from San Francisco International Airport to the Golden Gate Bridge?
# Result: 1
# ----------------
#
# Question: How has copper's price changed in the last week?
# Result: 1
# ----------------
#
# Question: What are primary colors?
# Result: 0
# ----------------
#
# Question: How did the First World War impact the global balance of power?
# Result: 0
# ----------------
#
# Question: What's the distance from Kansai International Airport to Osaka Castle as per local maps?
# Result: 1
# ----------------
#
# Question: What is poverty?
# Result: 0
# ----------------
#
# Question: Who are the prominent scientists working on Covid-19 vaccine research?
# Result: 1
# ----------------
#
# Question: When does Condor Flight DE 2062 land in FRA?
# Result: 1
# ----------------
#
# Question: What are the recent advancements in stem cell research?
# Result: 1
# ----------------
#
# Question: What did Robert Koch discover?
# Result: 0
# ----------------
#
# Question: What are the things to do in Vienna?
# Result: 1
# ----------------
#
# Question: Who brought mini-skirts into fashion?
# Result: 0
# ----------------
#
# Question: What was the average price of a sack of rice in 2006?
# Result: 1
# ----------------
#
# Question: Who invented Genetic Engineering?
# Result: 0
# ----------------
#
# Question: Who wrote the Communist Manifesto?
# Result: 0
# ----------------
#
# Question: What is the current state of global warming?
# Result: 0
# ----------------
#
# Question: What is populism?
# Result: 0
# ----------------
#
# Question: Who directed 'Brother Bear'?
# Result: 0
# ----------------
#
# Question: Who discovered the laws of planetary motion?
# Result: 0
# ----------------
#
# Question: What is SETI?
# Result: 0
# ----------------
#
# Question: Are there any exits row seats available on Delta Airlines Flight DL 22?
# Result: 1
# ----------------
#
# Question: What were the consequences of the War of the Roses in England?
# Result: 1
# ----------------
#
# Question: What is an asteroid?
# Result: 0
# ----------------
#
# Question: Who played Shrek in 'Shrek'?
# Result: 0
# ----------------
#
# Question: What are the local map references for the Vasa Museum in Stockholm?
# Result: 1
# ----------------
#
# Question: Who is the main antagonist in 'Hercules'?
# Result: 0
# ----------------
#
# Question: Who were the Axis Powers in World War II?
# Result: 0
# ----------------
#
# Question: Who discovered the neutron?
# Result: 0
# ----------------
#
# Question: What is the gate number for Flydubai Flight FZ 23?
# Result: 1
# ----------------
#
# Question: What is Article 5?
# Result: 1
# ----------------
#
# Question: What is a traditional dish in Vietnam?
# Result: 1
# ----------------
#
# Question: Who were the main figures during the rule of the Achaemenid Empire?
# Result: 0
# ----------------
#
# Question: What is the status of UEFA Euro Cup because of the pandemic?
# Result: 1
# ----------------
#
# Question: What significance did the Battle of Midway have in WWII?
# Result: 0
# ----------------
#
# Question: What is a childcare voucher?
# Result: 0
# ----------------
#
# Question: Who won the recent season of Drag Race?
# Result: 0
# ----------------
#
# Question: What is a tank top?
# Result: 0
# ----------------
#
# Question: What's the street view of the Yangtze River from the Bund in Shanghai?
# Result: 1
# ----------------
#
# Question: What are public goods?
# Result: 0
# ----------------
#
# Question: What is a foreclosed home?
# Result: 0
# ----------------
#
# Question: What is a castle tour?
# Result: 0
# ----------------
#
# Question: What was the cost of a kilogram of basil in 2008?
# Result: 1
# ----------------
#
# Question: When did British rule in India end?
# Result: 0
# ----------------
#
# Question: What is the Google customer service hotline in Spain?
# Result: 1
# ----------------
#
# Question: What did Zohar Manna contribute to computer science?
# Result: 0
# ----------------
#
# Question: What's the exact local map location for the Potala Palace in Tibet?
# Result: 1
# ----------------
#
# Question: What is the national drink of England?
# Result: 1
# ----------------
#
# Question: What is the University of Fraser Valley's customer service email?
# Result: 1
# ----------------
#
# Question: What is a ferry?
# Result: 0
# ----------------
#
# Question: What are some of the benefits of traveling?
# Result: 0
# ----------------
#
# Question: What is the physical location of Carleton University's campus?
# Result: 1
# ----------------
#
# Question: What is the term limit for a U.S. President?
# Result: 1
# ----------------
#
# Question: What was the cost of a barrel of crude oil in 2013?
# Result: 1
# ----------------
#
# Question: Who invented the polio vaccine?
# Result: 0
# ----------------
#
# Question: What was the price of live cattle per pound in the US in 1979?
# Result: 1
# ----------------
#
# Question: What was the price of oats in April 1992?
# Result: 1
# ----------------
#
# Question: What's the name of the local neighborhood where the maisons colorées painted houses are in Valparaiso, Chile?
# Result: 1
# ----------------
#
# Question: What is the helpline for the College of New Caledonia?
# Result: 1
# ----------------
#
# Question: Who painted 'The Night Watch'?
# Result: 0
# ----------------
#
# Question: Who invented the microwave oven?
# Result: 0
# ----------------
#
# Question: Are there any flight changes for American Airlines Flight AA 21?
# Result: 1
# ----------------
#
# Question: What is the current status of any banned substance in sports?
# Result: 0
# ----------------
#
# Question: What did Carl Friedrich Gauss contribute to mathematics and physics?
# Result: 0
# ----------------
#
# Question: What was Martin Luther King Jr's 'I Have a Dream' speech?
# Result: 0
# ----------------
#
# Question: What is the University College Cork's customer service hotline?
# Result: 1
# ----------------
#
# Question: What are the types of clouds?
# Result: 0
# ----------------
#
# Question: Who invented DNA fingerprinting?
# Result: 0
# ----------------
#
# Question: Who directed 'Moana'?
# Result: 0
# ----------------
#
# Question: What is space debris?
# Result: 0
# ----------------
#
# Question: What is the helpline for the University of Baghdad?
# Result: 0
# ----------------
#
# Question: Who voiced Oliver in 'Oliver & Company'?
# Result: 1
# ----------------
#
# Question: What were the causes and impacts of the October Revolution?
# Result: 1
# ----------------
#
# Question: How's the weather in Paris right now?
# Result: 1
# ----------------
#
# Question: Who is Thomas Edison?
# Result: 0
# ----------------
#
# Question: What was the Glorious Revolution?
# Result: 1
# ----------------
#
# Question: How much time does it take to reach the Louvre Museum from the Eiffel Tower by walking ?
# Result: 1
# ----------------
#
# Question: What was the cost of a kilogram of alfalfa in 2008?
# Result: 1
# ----------------
#
# Question: What were the causes and impacts of the Race for Africa?
# Result: 1
# ----------------
#
# Question: Which film won the Palme d'Or in the most recent Cannes Film Festival?
# Result: 1
# ----------------
#
# Question: What did Richard Dawkins propose in The Selfish Gene?
# Result: 0
# ----------------
#
# Question: What was the cost of a bushel of corn in 1965?
# Result: 1
# ----------------
#
# Question: What was the highest cost of a barrel of oil in 1985?
# Result: 1
# ----------------
#
# Question: Where is Tsinghua University's office?
# Result: 1
# ----------------
#
# Question: What is a turtleneck?
# Result: 0
# ----------------
#
# Question: What's the navigation information to reach the Great Sphinx from Downtown Giza in Egypt?
# Result: 1
# ----------------
#
# Question: What's the fastest route from Denver International Airport to the Denver Zoo?
# Result: 1
# ----------------
#
# Question: What is the recent update in the Ozone layer status?
# Result: 0
# ----------------
#
# Question: What is a pre-approval letter?
# Result: 0
# ----------------
#
# Question: Who discovered how to split an atom?
# Result: 0
# ----------------
#
# Question: What is the discovery of Horace Wells?
# Result: 1
# ----------------
#
# Question: Who invented the Thermionic valve?
# Result: 0
# ----------------
#
# Question: What was the cost of a pound of cotton in 2003?
# Result: 1
# ----------------
#
# Question: What was the Industrial Revolution?
# Result: 0
# ----------------
#
# Question: What was the name of the ship that brought the Pilgrims to North America?
# Result: 1
# ----------------
#
# Question: What led to the fall of the Berlin Wall?
# Result: 0
# ----------------
#
# Question: Who is Humphry Davy?
# Result: 0
# ----------------
#
# Question: What is a traveler's check?
# Result: 0
# ----------------
#
# Question: What is an atom?
# Result: 0
# ----------------
#
# Question: What was the price of rice in August 2005?
# Result: 1
# ----------------
#
# Question: What's the navigation data from Los Angeles's LAX Airport to Universal Studios Hollywood?
# Result: 1
# ----------------
#
# Question: Has Copa Airlines Flight CM 804 been rescheduled?
# Result: 1
# ----------------
#
# Question: Has Allegiant Air Flight G4 678 been cancelled?
# Result: 1
# ----------------
#
# Question: Has there been a change in the schedule for Qatar Airways Flight QR 108?
# Result: 1
# ----------------
#
# Question: How did the Treaty of Tordesillas impact relations between Portugal and Spain?
# Result: 1
# ----------------
#
# Question: What is bureaucracy?
# Result: 0
# ----------------
#
# Question: What does right-wing mean?
# Result: 0
# ----------------
#
# Question: Is there any extreme weather warnings in Cape Town today?
# Result: 1
# ----------------
#
# Question: What are the current weather conditions in Tokyo?
# Result: 1
# ----------------
#
# Question: What is the boarding gate for Emirates Flight EK 204?
# Result: 1
# ----------------
#
# Question: What are the most famous churches in Russia?
# Result: 1
# ----------------
#
# Question: What is the physical location of the European Union's headquarters?
# Result: 1
# ----------------
#
# Question: What is a chevron pattern?
# Result: 0
# ----------------
#
# Question: What was the cost of a pound of cacao beans in 2015?
# Result: 1
# ----------------
#
# Question: Who was behind the assassination of John F. Kennedy?
# Result: 1
# ----------------
#
# Question: What's the fastest route from Kings Cross St. Pancras Station to the London Eye?
# Result: 1
# ----------------
#
# Question: What are the places to visit in Spain?
# Result: 1
# ----------------
#
# Question: How do you avoid pickpockets when traveling?
# Result: 0
# ----------------
#
# Question: Who voiced Basil in 'The Great Mouse Detective'?
# Result: 0
# ----------------
#
# Question: What is the axis of the Earth?
# Result: 0
# ----------------
#
# Question: What are the local coordinates for the Plitvice Lakes National Park in Croatia?
# Result: 1
# ----------------
# 0.9168053244592346

# %%
from sklearn.metrics import precision_score, recall_score

y_true = test_data['y']
y_pred = test_data['y_pred']

precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)

f1 = (2 * precision * recall) / (precision + recall)

print("F1 равен:", f1)
# Out:
# F1 равен: 0.912280701754386
